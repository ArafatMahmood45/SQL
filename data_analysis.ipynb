# %%
import pandas as pd
data = pd.read_csv("data4.csv")
print(data)
# Out:
#            date region  beverages_units  food_units  electronics_units  \
# 0    2020-06-01  SIN51              194         188                 68
# 1             -  DUB53               28         149                141
# 2             -  IAD77               83         154                 33
# 3             -  PDX79               56          21                 87
# 4    2020-06-02  SIN51              118          12                 10
# ..          ...    ...              ...         ...                ...
# 115           -  PDX79               44         157                 38
# 116  2020-06-30  SIN51              158         109                 25
# 117           -  DUB53               14           2                 11
# 118           -  IAD77               21          38                 47
# 119           -  PDX79              105         165                 43
#
#      clothes_units  tools_units
# 0               93          261
# 1              111          207
# 2              211          143
# 3               27          274
# 4              150          152
# ..             ...          ...
# 115            101           49
# 116             17           45
# 117             11           38
# 118             78            2
# 119            135            8
#
# [120 rows x 7 columns]

# %%
data["date"].isna().sum()
# Out:
# np.int64(0)

# %%
data["date"] = data["date"].replace("-", pd.NA)
data["date"] = pd.to_datetime(data["date"])
data
# Out:
#           date region  beverages_units  food_units  electronics_units  \
# 0   2020-06-01  SIN51              194         188                 68
# 1          NaT  DUB53               28         149                141
# 2          NaT  IAD77               83         154                 33
# 3          NaT  PDX79               56          21                 87
# 4   2020-06-02  SIN51              118          12                 10
# ..         ...    ...              ...         ...                ...
# 115        NaT  PDX79               44         157                 38
# 116 2020-06-30  SIN51              158         109                 25
# 117        NaT  DUB53               14           2                 11
# 118        NaT  IAD77               21          38                 47
# 119        NaT  PDX79              105         165                 43
#
#      clothes_units  tools_units
# 0               93          261
# 1              111          207
# 2              211          143
# 3               27          274
# 4              150          152
# ..             ...          ...
# 115            101           49
# 116             17           45
# 117             11           38
# 118             78            2
# 119            135            8
#
# [120 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               30 non-null     datetime64[ns]
#  1   region             120 non-null    object
#  2   beverages_units    120 non-null    int64
#  3   food_units         120 non-null    int64
#  4   electronics_units  120 non-null    int64
#  5   clothes_units      120 non-null    int64
#  6   tools_units        120 non-null    int64
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 6.7+ KB

# %%
data["region"].value_counts()
# Out:
# region
# SIN51    30
# DUB53    30
# IAD77    30
# PDX79    30
# Name: count, dtype: int64

# %%
data["date"] = data["date"].ffill()

# %%
data["date"].value_counts()
# Out:
# date
# 2020-06-01    4
# 2020-06-02    4
# 2020-06-03    4
# 2020-06-04    4
# 2020-06-05    4
# 2020-06-06    4
# 2020-06-07    4
# 2020-06-08    4
# 2020-06-09    4
# 2020-06-10    4
# 2020-06-11    4
# 2020-06-12    4
# 2020-06-13    4
# 2020-06-14    4
# 2020-06-15    4
# 2020-06-16    4
# 2020-06-17    4
# 2020-06-18    4
# 2020-06-19    4
# 2020-06-20    4
# 2020-06-21    4
# 2020-06-22    4
# 2020-06-23    4
# 2020-06-24    4
# 2020-06-25    4
# 2020-06-26    4
# 2020-06-27    4
# 2020-06-28    4
# 2020-06-29    4
# 2020-06-30    4
# Name: count, dtype: int64

# %%
data
# Out:
#           date region  beverages_units  food_units  electronics_units  \
# 0   2020-06-01  SIN51              194         188                 68
# 1   2020-06-01  DUB53               28         149                141
# 2   2020-06-01  IAD77               83         154                 33
# 3   2020-06-01  PDX79               56          21                 87
# 4   2020-06-02  SIN51              118          12                 10
# ..         ...    ...              ...         ...                ...
# 115 2020-06-29  PDX79               44         157                 38
# 116 2020-06-30  SIN51              158         109                 25
# 117 2020-06-30  DUB53               14           2                 11
# 118 2020-06-30  IAD77               21          38                 47
# 119 2020-06-30  PDX79              105         165                 43
#
#      clothes_units  tools_units
# 0               93          261
# 1              111          207
# 2              211          143
# 3               27          274
# 4              150          152
# ..             ...          ...
# 115            101           49
# 116             17           45
# 117             11           38
# 118             78            2
# 119            135            8
#
# [120 rows x 7 columns]

# %%
data.to_csv("new_data.csv", index=False)
